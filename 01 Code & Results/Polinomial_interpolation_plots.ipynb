# %%
import numpy
import matplotlib.pyplot as plt


x1 = [0,0.5,1,1.5,2,2.5,3]            # Hours
y1 = [82,155,141,103,89,85,85]        # mg/dl

mymodel1 = numpy.poly1d(numpy.polyfit(x1, y1, 5))

myline = numpy.linspace(0, 3, 100)

plt.scatter(x1[0:5], y1[0:5])
plt.plot(myline, mymodel1(myline),linewidth=20.0, alpha=0.1)
plt.xlabel("Time (hours)")
plt.ylabel("Blood Glucose")
plt.show()

# %%
import numpy
import matplotlib.pyplot as plt


x2 = [0,0.5,1,1.5,2]            # Hours
y2 = [82,118,127,148,146]        # mg/dl

mymodel2 = numpy.poly1d(numpy.polyfit(x2, y2, 2))

myline = numpy.linspace(0, 3, 100)

plt.scatter(x2, y2)
plt.plot(myline, mymodel2(myline),linewidth=20.0, alpha=0.1)
plt.show()

# %%
import numpy
import matplotlib.pyplot as plt


x3 = [0,0.5,1,1.5,2]            # Hours
y3 = [92,133,72,87,92]         # mg/dl

mymodel3 = numpy.poly1d(numpy.polyfit(x3, y3, 4))

myline = numpy.linspace(0, 2, 100)

plt.scatter(x3, y3)
plt.plot(myline, mymodel3(myline),linewidth=20.0, alpha=0.1)
plt.show()

# %%
import numpy
import matplotlib.pyplot as plt


x4 = [0,0.5,1,1.5,2]            # Hours
y4 = [ 157. , 185.,  232. , 216., 197.]        # mg/dl

mymodel4 = numpy.poly1d(numpy.polyfit(x4, y4, 3))

myline = numpy.linspace(0, 2, 100)

plt.scatter(x4, y4)
plt.plot(myline, mymodel4(myline),linewidth=20.0, alpha=0.1)
plt.show()

# %%
#fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(16,14))
fig, axs = plt.subplots(2, 2, figsize=(16,14))

for ax in axs.flat:
    ax.set(xlabel='Time (hours)', ylabel='Blood Glucose')

# Hide x labels and tick labels for top plots and y ticks for right plots.
#for ax in axs.flat:
 #   ax.label_outer()


fig.suptitle('OGTT Patients')
axs[0,0].plot(myline, mymodel1(myline),linewidth=30.0, alpha=0.1)
axs[0,0].scatter(x1[0:5], y1[0:5])
axs[0, 0].set_title('a )')
axs[0,1].plot(myline, mymodel2(myline),linewidth=30.0, alpha=0.1)
axs[0,1].scatter(x2, y2)
axs[0, 1].set_title('b )')
axs[1,0].plot(myline, mymodel3(myline),linewidth=30.0, alpha=0.1)
axs[1,0].scatter(x3, y3)
axs[1, 0].set_title('c )')
axs[1,1].plot(myline, mymodel4(myline),linewidth=30.0, alpha=0.1)
axs[1,1].scatter(x4, y4)
axs[1, 1].set_title('d )')
# Out:
# Text(0.5, 1.0, 'd )')

# %%
import numpy
import matplotlib.pyplot as plt


x1 = [0,0.5,1,1.5,2,2.5,3]            # Hours
y1 = [70,70,148,148,116,97,97]        # mg/dl

mymodel1 = numpy.poly1d(numpy.polyfit(x1, y1, 5))

myline = numpy.linspace(0, 3, 100)

plt.scatter(x1[0:5], y1[0:5])
plt.plot(myline, mymodel1(myline),linewidth=20.0, alpha=0.1)
plt.xlabel("Time (hours)")
plt.ylabel("Blood Glucose")
plt.show()

# %%
import numpy
import matplotlib.pyplot as plt


x2 = [0,0.5,1,1.5,2,2.5,3]            # Hours
y2 = [79,79,157,157,116,84,84]        # mg/dl

mymodel2 = numpy.poly1d(numpy.polyfit(x2, y2, 5))

myline = numpy.linspace(0, 3, 100)

plt.scatter(x2[0:5], y2[0:5])
plt.plot(myline, mymodel2(myline),linewidth=20.0, alpha=0.1)
plt.xlabel("Time (hours)")
plt.ylabel("Blood Glucose")
plt.show()

# %%
import numpy
import matplotlib.pyplot as plt


x3 = [0,0.5,1,1.5,2,2.5,3]            # Hours
y3 = [82,82,94,94,102,102,102]        # mg/dl

mymodel3 = numpy.poly1d(numpy.polyfit(x3, y3, 3))

myline = numpy.linspace(0, 3, 100)

plt.scatter(x3[0:5], y3[0:5])
plt.plot(myline, mymodel3(myline),linewidth=20.0, alpha=0.1)
plt.xlabel("Time (hours)")
plt.ylabel("Blood Glucose")
plt.show()

# %%
import numpy
import matplotlib.pyplot as plt


x4 = [0,0.5,1,1.5,2,2.5,3]            # Hours
y4 = [95,95,180,180,155,155,140]        # mg/dl

mymodel4 = numpy.poly1d(numpy.polyfit(x4, y4, 4))

myline = numpy.linspace(0, 3, 100)

plt.scatter(x4[0:5], y4[0:5])
plt.plot(myline, mymodel4(myline),linewidth=20.0, alpha=0.1)
plt.xlabel("Time (hours)")
plt.ylabel("Blood Glucose")
plt.show()

# %%
#fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(16,14))
fig, axs = plt.subplots(2, 2, figsize=(16,14))

for ax in axs.flat:
    ax.set(xlabel='Time (hours)', ylabel='Blood Glucose')

# Hide x labels and tick labels for top plots and y ticks for right plots.
#for ax in axs.flat:
 #   ax.label_outer()


fig.suptitle('OGTT Patients')
axs[0,0].plot(myline, mymodel1(myline),linewidth=30.0, alpha=0.1)
axs[0,0].scatter(x1, y1)
axs[0,0].set_title('e )')
axs[0,1].plot(myline, mymodel2(myline),linewidth=30.0, alpha=0.1)
axs[0,1].scatter(x2, y2)
axs[0, 1].set_title('f )')
axs[1,0].plot(myline, mymodel3(myline),linewidth=30.0, alpha=0.1)
axs[1,0].scatter(x3, y3)
axs[1, 0].set_title('g )')
axs[1,1].plot(myline, mymodel4(myline),linewidth=30.0, alpha=0.1)
axs[1,1].scatter(x4, y4)
axs[1, 1].set_title('h )')
# Out:
# Text(0.5, 1.0, 'h )')

# %% [markdown]
# #segunda grafica

# %%
import numpy
import matplotlib.pyplot as plt


x1 = [0,0.5,1,1.5,2,2.5,3]            # Hours
y1 = [84,84,84,84,164,164,164]        # mg/dl

mymodel1 = numpy.poly1d(numpy.polyfit(x1, y1, 4))

myline = numpy.linspace(0, 3, 100)

plt.scatter(x1[0:5], y1[0:5])
plt.plot(myline, mymodel1(myline),linewidth=20.0, alpha=0.1)
plt.xlabel("Time (hours)")
plt.ylabel("Blood Glucose")
plt.show()

# %%
import numpy
import matplotlib.pyplot as plt


x2 = [0,0.5,1,1.5,2,2.5,3]            # Hours
y2 = [73,73,99,99,82,82,82]        # mg/dl

mymodel2 = numpy.poly1d(numpy.polyfit(x2, y2, 4))

myline = numpy.linspace(0, 3, 100)

plt.scatter(x2[0:5], y2[0:5])
plt.plot(myline, mymodel2(myline),linewidth=20.0, alpha=0.1)
plt.xlabel("Time (hours)")
plt.ylabel("Blood Glucose")
plt.show()

# %%
import numpy
import matplotlib.pyplot as plt


x3 = [0,0.5,1,1.5,2,2.5,3]            # Hours
y3 = [61,61,94,94,90,90,90]        # mg/dl

mymodel3 = numpy.poly1d(numpy.polyfit(x3, y3, 3))

myline = numpy.linspace(0, 3, 100)

plt.scatter(x3[0:5], y3[0:5])
plt.plot(myline, mymodel3(myline),linewidth=20.0, alpha=0.1)
plt.xlabel("Time (hours)")
plt.ylabel("Blood Glucose")
plt.show()

# %%
import numpy
import matplotlib.pyplot as plt


x4 = [0,0.5,1,1.5,2,2.5,3]            # Hours
y4 = [100,100,100,100,149,149,149]        # mg/dl

mymodel4 = numpy.poly1d(numpy.polyfit(x4, y4, 4))

myline = numpy.linspace(0, 3, 100)

plt.scatter(x4[0:5], y4[0:5])
plt.plot(myline, mymodel4(myline),linewidth=20.0, alpha=0.1)
plt.xlabel("Time (hours)")
plt.ylabel("Blood Glucose")
plt.show()

# %%
#fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(16,14))
fig, axs = plt.subplots(2, 2, figsize=(16,14))

for ax in axs.flat:
    ax.set(xlabel='Time (hours)', ylabel='Blood Glucose')

# Hide x labels and tick labels for top plots and y ticks for right plots.
#for ax in axs.flat:
 #   ax.label_outer()


fig.suptitle('OGTT Patients')
axs[0,0].plot(myline, mymodel1(myline),linewidth=30.0, alpha=0.1)
axs[0,0].scatter(x1[0:5], y1[0:5])
axs[0, 0].set_title('i )')
axs[0,1].plot(myline, mymodel2(myline),linewidth=30.0, alpha=0.1)
axs[0,1].scatter(x2, y2)
axs[0,1].set_title('j )')
axs[1,0].plot(myline, mymodel3(myline),linewidth=30.0, alpha=0.1)
axs[1,0].scatter(x3, y3)
axs[1, 0].set_title('k )')
axs[1,1].plot(myline, mymodel4(myline),linewidth=30.0, alpha=0.1)
axs[1,1].scatter(x4, y4)
axs[1, 1].set_title('l )')
# Out:
# Text(0.5, 1.0, 'l )')

# %% [markdown]
# #tercera grafica

# %%
import numpy
import matplotlib.pyplot as plt


x1 = [0,0.5,1,1.5,2,2.5,3]            # Hours
y1 = [63,63,63,63,87,87,87]        # mg/dl

mymodel1 = numpy.poly1d(numpy.polyfit(x1, y1, 4))

myline = numpy.linspace(0, 3, 100)

plt.scatter(x1[0:5], y1[0:5])
plt.plot(myline, mymodel1(myline),linewidth=20.0, alpha=0.1)
plt.xlabel("Time (hours)")
plt.ylabel("Blood Glucose")
plt.show()

# %%
import numpy
import matplotlib.pyplot as plt


x2 = [0,0.5,1,1.5,2,2.5,3]            # Hours
y2 = [75,75,75,75,91,91,91]        # mg/dl

mymodel2 = numpy.poly1d(numpy.polyfit(x2, y2, 4))

myline = numpy.linspace(0, 3, 100)

plt.scatter(x2[0:5], y2[0:5])
plt.plot(myline, mymodel2(myline),linewidth=20.0, alpha=0.1)
plt.xlabel("Time (hours)")
plt.ylabel("Blood Glucose")
plt.show()

# %%
import numpy
import matplotlib.pyplot as plt


x3 = [0,0.5,1,1.5,2,2.5,3]            # Hours
y3 = [117,117,145,145,98,98,98]        # mg/dl

mymodel3 = numpy.poly1d(numpy.polyfit(x3, y3, 4))

myline = numpy.linspace(0, 3, 100)

plt.scatter(x3[0:5], y3[0:5])
plt.plot(myline, mymodel3(myline),linewidth=20.0, alpha=0.1)
plt.xlabel("Time (hours)")
plt.ylabel("Blood Glucose")
plt.show()

# %%
import numpy
import matplotlib.pyplot as plt


x4 = [0,0.5,1,1.5,2,2.5,3]            # Hours
y4 = [120,120,120,120,136,136,136]        # mg/dl

mymodel4 = numpy.poly1d(numpy.polyfit(x4, y4, 4))

myline = numpy.linspace(0, 3, 100)

plt.scatter(x4[0:5], y4[0:5])
plt.plot(myline, mymodel4(myline),linewidth=20.0, alpha=0.1)
plt.xlabel("Time (hours)")
plt.ylabel("Blood Glucose")
plt.show()

# %%
#fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(16,14))
fig, axs = plt.subplots(2, 2, figsize=(16,14))

for ax in axs.flat:
    ax.set(xlabel='Time (hours)', ylabel='Blood Glucose')

# Hide x labels and tick labels for top plots and y ticks for right plots.
#for ax in axs.flat:
 #   ax.label_outer()


fig.suptitle('OGTT Patients')
axs[0,0].plot(myline, mymodel1(myline),linewidth=30.0, alpha=0.1)
axs[0,0].scatter(x1[0:5], y1[0:5])
axs[0, 0].set_title('m )')
axs[0,1].plot(myline, mymodel2(myline),linewidth=30.0, alpha=0.1)
axs[0,1].scatter(x2, y2)
axs[0, 1].set_title('n )')
axs[1,0].plot(myline, mymodel3(myline),linewidth=30.0, alpha=0.1)
axs[1,0].scatter(x3, y3)
axs[1, 0].set_title('o )')
axs[1,1].plot(myline, mymodel4(myline),linewidth=30.0, alpha=0.1)
axs[1,1].scatter(x4, y4)
axs[1, 1].set_title('p )')
# Out:
# Text(0.5, 1.0, 'p )')

# %%
axs.flat
